# %% [markdown]
# <a href="https://colab.research.google.com/github/illiyas-sha/Colab-Notebook/blob/main/Time_Series_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Reading The Datasets

# %%
import pandas as pd

data = pd.read_csv('/content/sample_data/Month_Value_1.csv')
data.head()
# Out:
#        Period  ...  The_average_annual_payroll_of_the_region
# 0  01.01.2015  ...                                30024676.0
# 1  01.02.2015  ...                                30024676.0
# 2  01.03.2015  ...                                30024676.0
# 3  01.04.2015  ...                                30024676.0
# 4  01.05.2015  ...                                30024676.0
#
# [5 rows x 5 columns]

# %% [markdown]
# ## Shape of the data

# %%
data.shape
# Out:
# (96, 5)

# %% [markdown]
# ## Line chart of the data

# %%
data.plot.line(x=None,y=None)

# %% [markdown]
# Dropping other columns

# %%
data = data.drop('Sales_quantity', 1)
data = data.drop('Average_cost', 1)
data = data.drop('The_average_annual_payroll_of_the_region', 1)

# %%
data.head()
# Out:
#        Period       Revenue
# 0  01.01.2015  1.601007e+07
# 1  01.02.2015  1.580759e+07
# 2  01.03.2015  2.204715e+07
# 3  01.04.2015  1.881458e+07
# 4  01.05.2015  1.402148e+07

# %% [markdown]
# Period vs Revenue line chart

# %%
data.plot.line(x=None,y=None)
